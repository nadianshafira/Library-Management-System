# %%
class book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    
    def __str__(self):
        return f"{self.title} by {self.author}"
    
class libraryCatalogue:
    def __init__(self):
        self.books = []
    
    def add_book(self, book):
        self.books.append(book)
    
    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)
    
    def search_book(self, title=None, author=None):
        results = []
        for book in self.books:
            if (title is None or title.lower() in book.title.lower()) and \
               (author is None or author.lower() in book.author.lower()) and \
               (genre is None or genre.lower() in book.genre.lower()):
                results.append(book)
        return results
    
    #create some books

book1 = book("cara cepet pinter python", "hacktiv8")
book2 = book("jadi data scientist", "nadia")
book3 = book("yuk cepet kaya", "nabilla")

#bikin library catalogue
catalogue = libraryCatalogue()

#add books
catalogue.add_book(book1)
catalogue.add_book(book2)
catalogue.add_book(book3)

#search books
search_book = catalogue.search_book("nadia")
for book in search_book:
    print(book)

#remove book
catalogue.remove_book("hacktiv8")

#print remaining books
for book in catalogue.books:
    print(book)
